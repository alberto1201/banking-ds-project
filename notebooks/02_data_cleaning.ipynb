# %% [markdown]
#  # Fase 2 — Limpieza de datos
#
# ## Objetivos
# - Tratar valores especiales (98) en variables de mora
# - Imputar nulos en MonthlyIncome y NumberOfDependents
# - Tratar outliers extremos
#
# ## Dataset de entrada
# `data/raw/cs-training.csv` — 150.000 filas × 11 columnas

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme(style='whitegrid')

# Cargamos siempre desde raw - nunca modificamoas el original 
df = pd.read_csv('../data/raw/cs-training.csv', index_col=0)


print(f"Dataset cargado: {df.shape[0]} filas x {df.shape[1]} columnas")
# Out:
# Dataset cargado: 150000 filas x 11 columnas
